# %% [markdown]
# <a href="https://colab.research.google.com/github/runtorain/basic_computervision/blob/main/LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Change You Runtime to T4

# %%
#Install Library YOLO
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.4/617.4 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !yolo track model=yolov8n.pt source='/content/car.mp4'  #
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 292MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.9 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.1s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (1/1440) /content/car.mp4: 384x640 10 cars, 1 bus, 95.5ms
# video 1/1 (2/1440) /content/car.mp4: 384x640 10 cars, 1 bus, 6.4ms
# video 1/1 (3/1440) /content/car.mp4: 384x640 10 cars, 1 bus, 1 truck, 6.1ms
# video 1/1 (4/1440) /content/car.mp4: 384x640 11 cars, 1 bus, 1 truck, 6.1ms
# video 1/1 (5/1440) /content/car.mp4: 384x640 11 cars, 1 bus, 1 truck, 6.4ms
# ...

# %%
# !yolo  detect predict model=yolov8n.pt source='/content/city.jpg'  #
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/city.jpg: 384x640 21 persons, 7 cars, 115.1ms
# Speed: 3.4ms preprocess, 115.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
